# %% [markdown]
# # 1. Read CSV

# %%
import pandas as pd
df = pd.read_csv("personality_dataset.csv")

# %% [markdown]
# #   2. Print Top 5 rows of dataset:

# %%
df.head()
# Out:
#    Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0               4.0         No                      4.0            6.0
# 1               9.0        Yes                      0.0            0.0
# 2               9.0        Yes                      1.0            2.0
# 3               0.0         No                      6.0            7.0
# 4               3.0         No                      9.0            4.0
#
#   Drained_after_socializing  Friends_circle_size  Post_frequency Personality
# 0                        No                 13.0             5.0   Extrovert
# 1                       Yes                  0.0             3.0   Introvert
# 2                       Yes                  5.0             2.0   Introvert
# 3                        No                 14.0             8.0   Extrovert
# 4                        No                  8.0             5.0   Extrovert

# %% [markdown]
# # 3. Print Bottom 5 rows of dataset:

# %%
df.tail()
# Out:
#       Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 2895               3.0         No                      7.0            6.0
# 2896               3.0         No                      8.0            3.0
# 2897               4.0        Yes                      1.0            1.0
# 2898              11.0        Yes                      1.0            NaN
# 2899               3.0         No                      6.0            6.0
#
#      Drained_after_socializing  Friends_circle_size  Post_frequency  \
# 2895                        No                  6.0             6.0
# 2896                        No                 14.0             9.0
# 2897                       Yes                  4.0             0.0
# 2898                       Yes                  2.0             0.0
# 2899                        No                  6.0             9.0
#
#      Personality
# 2895   Extrovert
# 2896   Extrovert
# 2897   Introvert
# 2898   Introvert
# 2899   Extrovert

# %% [markdown]
# # 4. Print Number of Rows and Columns in dataset:

# %%
print('rows: ', df.shape[0])
print('columns: ', df.shape[1])
# Out:
# rows:  2900
# columns:  8

# %% [markdown]
# # 5. Print/Determine all the null columns in dataset:

# %%
df.isnull().sum()
# Out:
# Time_spent_Alone             63
# Stage_fear                   73
# Social_event_attendance      62
# Going_outside                66
# Drained_after_socializing    52
# Friends_circle_size          77
# Post_frequency               65
# Personality                   0
# dtype: int64

# %% [markdown]
# # 6. Filling null values using mean / median / mode:

# %%
df = df.fillna(df.mean)
df = df.fillna(df.median)
df = df.fillna(df.mode)

# %% [markdown]
# # 7. Print datatype of each column:

# %%
df.dtypes
# Out:
# Time_spent_Alone             object
# Stage_fear                   object
# Social_event_attendance      object
# Going_outside                object
# Drained_after_socializing    object
# Friends_circle_size          object
# Post_frequency               object
# Personality                  object
# dtype: object
